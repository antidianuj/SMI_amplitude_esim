# %%
# %reset
# Out:
# Once deleted, variables cannot be recovered. Proceed (y/[n])? y

# %%
import tensorflow as tf
physical_devices = tf.config.list_physical_devices('GPU') 
tf.config.experimental.set_memory_growth(physical_devices[0], True)

# %%
from sklearn.utils import shuffle
import numpy as np
from numpy import genfromtxt
X=np.zeros((847,8000,1))
Y=np.zeros((847,2))


for i in range(847):
  my_data = genfromtxt("C:/Users/dianu/Downloads/SM/SM_Gen/SM"+str(i+1)+".csv", delimiter=',')
  my_data2 = genfromtxt("C:/Users/dianu/Downloads/SMy/SM_id_Gen/SMy"+str(i+1)+".csv", delimiter=',')
  X[i,:,0]=my_data
  Y[i,:]=my_data2

# %%
X, Y = shuffle(X, Y)

# %%
# Split the dataset
split_train = int(len(X)*0.7)
split_valid = int(len(X)*0.9)
 
    # Train

X_train = X[:split_train, [0],:]; y_train=Y[:split_train, :]

# Valid

X_valid = X[split_train:split_valid, [0],:]; y_valid=Y[split_train:split_valid,:]

# Test

X_test = X[split_valid:, [0],:]; y_test=Y[split_valid:,:]

print(X_train.shape, y_train.shape)
print(X_valid.shape, y_valid.shape)
print(X_test.shape, y_test.shape)
# Out:
# (592, 8000, 1) (592, 2)
# (170, 8000, 1) (170, 2)
# (85, 8000, 1) (85, 2)

# %%
#Utilizing 1D Convolution Model
import tensorflow as tf
from tensorflow import keras
from keras.models import Sequential
from keras.layers import Dense
from keras.layers import Flatten
from keras.layers import Dropout
from keras.layers.convolutional import Conv1D
from keras.layers.convolutional import MaxPooling1D

# %%
n_timesteps=8000
n_features=1
n_outputs=2


model = Sequential()
model.add(Conv1D(filters=16, kernel_size=7, activation='relu', input_shape=(n_timesteps,n_features)))
model.add(MaxPooling1D(pool_size=2))
model.add(Conv1D(filters=32, kernel_size=7, activation='relu'))
model.add(MaxPooling1D(pool_size=2))
model.add(Conv1D(filters=64, kernel_size=7, activation='relu'))
model.add(MaxPooling1D(pool_size=2))
model.add(Conv1D(filters=128, kernel_size=7, activation='relu'))
model.add(MaxPooling1D(pool_size=2))
model.add(Flatten())
model.add(Dropout(0.1))
model.add(Dense(100, activation='relu'))
model.add(Dense(50, activation='relu'))
model.add(Dense(n_outputs))
model.compile(loss='mse', optimizer='rmsprop', metrics=['accuracy'])

model.summary()
# Out:
# Model: "sequential"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# conv1d (Conv1D)              (None, 7994, 16)          128
# _________________________________________________________________
# max_pooling1d (MaxPooling1D) (None, 3997, 16)          0
# _________________________________________________________________
# conv1d_1 (Conv1D)            (None, 3991, 32)          3616
# _________________________________________________________________
# max_pooling1d_1 (MaxPooling1 (None, 1995, 32)          0
# _________________________________________________________________
# conv1d_2 (Conv1D)            (None, 1989, 64)          14400
# _________________________________________________________________
# max_pooling1d_2 (MaxPooling1 (None, 994, 64)           0
# _________________________________________________________________
# conv1d_3 (Conv1D)            (None, 988, 128)          57472
# _________________________________________________________________
# max_pooling1d_3 (MaxPooling1 (None, 494, 128)          0
# _________________________________________________________________
# flatten (Flatten)            (None, 63232)             0
# _________________________________________________________________
# dropout (Dropout)            (None, 63232)             0
# _________________________________________________________________
# dense (Dense)                (None, 100)               6323300
# _________________________________________________________________
# dense_1 (Dense)              (None, 50)                5050
# _________________________________________________________________
# dense_2 (Dense)              (None, 2)                 102
# =================================================================
# Total params: 6,404,068
# Trainable params: 6,404,068
# Non-trainable params: 0
# _________________________________________________________________

# %%
history=model.fit(X_train, y_train, epochs=100,
                    validation_data=(X_valid, y_valid))
# Out:
# Epoch 1/100
# 19/19 [==============================] - 23s 110ms/step - loss: 64.2269 - accuracy: 0.6027 - val_loss: 1.6818 - val_accuracy: 0.5706
# Epoch 2/100
# 19/19 [==============================] - 1s 59ms/step - loss: 1.6395 - accuracy: 0.6611 - val_loss: 0.7822 - val_accuracy: 0.8412
# Epoch 3/100
# 19/19 [==============================] - 1s 59ms/step - loss: 1.4866 - accuracy: 0.7962 - val_loss: 0.5844 - val_accuracy: 0.8529
# Epoch 4/100
# 19/19 [==============================] - 1s 59ms/step - loss: 1.4334 - accuracy: 0.8425 - val_loss: 0.3301 - val_accuracy: 0.8647
# Epoch 5/100
# 19/19 [==============================] - 1s 59ms/step - loss: 1.2942 - accuracy: 0.8655 - val_loss: 1.1567 - val_accuracy: 0.8706s - loss: 1.015
# Epoch 6/100
# 19/19 [==============================] - 1s 59ms/step - loss: 1.3646 - accuracy: 0.8931 - val_loss: 0.2003 - val_accuracy: 0.9353
# Epoch 7/100
# 19/19 [==============================] - 1s 59ms/step - loss: 1.2139 - accuracy: 0.8547 - val_loss: 1.4910 - val_accuracy: 0.9000
# Epoch 8/100
# 19/19 [==============================] - 1s 59ms/step - loss: 1.0618 - accuracy: 0.9301 - val_loss: 0.4142 - val_accuracy: 0.9529
# Epoch 9/100
# 19/19 [==============================] - 1s 60ms/step - loss: 0.7892 - accuracy: 0.9134 - val_loss: 0.3935 - val_accuracy: 0.9706
# Epoch 10/100
# 19/19 [==============================] - 1s 59ms/step - loss: 0.5751 - accuracy: 0.9477 - val_loss: 3.7569 - val_accuracy: 0.9706
# Epoch 11/100
# 19/19 [==============================] - 1s 59ms/step - loss: 0.9157 - accuracy: 0.9440 - val_loss: 0.1095 - val_accuracy: 0.9647
# Epoch 12/100
# 19/19 [==============================] - 1s 59ms/step - loss: 0.3726 - accuracy: 0.9427 - val_loss: 2.4450 - val_accuracy: 0.9118
# Epoch 13/100
# 19/19 [==============================] - 1s 58ms/step - loss: 0.7815 - accuracy: 0.9347 - val_loss: 0.2119 - val_accuracy: 0.9706
# Epoch 14/100
# 19/19 [==============================] - 1s 57ms/step - loss: 0.3646 - accuracy: 0.9395 - val_loss: 0.6069 - val_accuracy: 0.9529
# Epoch 15/100
# 19/19 [==============================] - 1s 57ms/step - loss: 0.4981 - accuracy: 0.9346 - val_loss: 0.2064 - val_accuracy: 0.9588
# Epoch 16/100
# 19/19 [==============================] - 1s 56ms/step - loss: 0.3425 - accuracy: 0.9418 - val_loss: 0.5176 - val_accuracy: 0.8647
# Epoch 17/100
# 19/19 [==============================] - 1s 57ms/step - loss: 0.4581 - accuracy: 0.9142 - val_loss: 0.2295 - val_accuracy: 0.9706
# Epoch 18/100
# 19/19 [==============================] - 1s 58ms/step - loss: 0.4178 - accuracy: 0.9467 - val_loss: 1.0022 - val_accuracy: 0.8824
# Epoch 19/100
# 19/19 [==============================] - 1s 59ms/step - loss: 0.3540 - accuracy: 0.9468 - val_loss: 0.5817 - val_accuracy: 0.9647
# Epoch 20/100
# 19/19 [==============================] - 1s 59ms/step - loss: 0.4234 - accuracy: 0.9411 - val_loss: 0.3180 - val_accuracy: 0.9765
# Epoch 21/100
# 19/19 [==============================] - 1s 59ms/step - loss: 0.3952 - accuracy: 0.9515 - val_loss: 0.7938 - val_accuracy: 0.9706
# Epoch 22/100
# 19/19 [==============================] - 1s 60ms/step - loss: 0.3595 - accuracy: 0.9373 - val_loss: 0.0609 - val_accuracy: 0.9765
# Epoch 23/100
# 19/19 [==============================] - 1s 59ms/step - loss: 0.1754 - accuracy: 0.9450 - val_loss: 0.2357 - val_accuracy: 0.9059
# Epoch 24/100
# 19/19 [==============================] - 1s 59ms/step - loss: 0.3080 - accuracy: 0.9122 - val_loss: 0.7466 - val_accuracy: 0.9235
# Epoch 25/100
# 19/19 [==============================] - 1s 59ms/step - loss: 0.3016 - accuracy: 0.9527 - val_loss: 0.0923 - val_accuracy: 0.9412
# Epoch 26/100
# 19/19 [==============================] - 1s 59ms/step - loss: 0.2237 - accuracy: 0.9382 - val_loss: 0.3599 - val_accuracy: 0.9765
# Epoch 27/100
# 19/19 [==============================] - 1s 59ms/step - loss: 0.3611 - accuracy: 0.9662 - val_loss: 0.1090 - val_accuracy: 0.9118
# Epoch 28/100
# 19/19 [==============================] - 1s 59ms/step - loss: 0.2460 - accuracy: 0.9476 - val_loss: 0.3469 - val_accuracy: 0.9647
# Epoch 29/100
# 19/19 [==============================] - 1s 60ms/step - loss: 0.2808 - accuracy: 0.9441 - val_loss: 0.0843 - val_accuracy: 0.9765
# Epoch 30/100
# 19/19 [==============================] - 1s 59ms/step - loss: 0.1185 - accuracy: 0.9579 - val_loss: 0.1752 - val_accuracy: 0.9706
# Epoch 31/100
# 19/19 [==============================] - 1s 59ms/step - loss: 0.2324 - accuracy: 0.9599 - val_loss: 0.1218 - val_accuracy: 0.9294
# Epoch 32/100
# 19/19 [==============================] - 1s 58ms/step - loss: 0.1769 - accuracy: 0.9515 - val_loss: 0.1077 - val_accuracy: 0.9529
# Epoch 33/100
# 19/19 [==============================] - 1s 60ms/step - loss: 0.1694 - accuracy: 0.9711 - val_loss: 0.3886 - val_accuracy: 0.9529
# Epoch 34/100
# 19/19 [==============================] - 1s 59ms/step - loss: 0.2363 - accuracy: 0.9518 - val_loss: 0.2214 - val_accuracy: 0.9824
# Epoch 35/100
# 19/19 [==============================] - 1s 58ms/step - loss: 0.2216 - accuracy: 0.9566 - val_loss: 0.2198 - val_accuracy: 0.8765
# Epoch 36/100
# 19/19 [==============================] - 1s 59ms/step - loss: 0.2414 - accuracy: 0.9723 - val_loss: 0.0717 - val_accuracy: 0.9706
# Epoch 37/100
# 19/19 [==============================] - 1s 59ms/step - loss: 0.1905 - accuracy: 0.9470 - val_loss: 0.2495 - val_accuracy: 0.9647
# Epoch 38/100
# 19/19 [==============================] - 1s 59ms/step - loss: 0.1805 - accuracy: 0.9759 - val_loss: 0.0540 - val_accuracy: 0.9647
# Epoch 39/100
# 19/19 [==============================] - 1s 59ms/step - loss: 0.1660 - accuracy: 0.9578 - val_loss: 0.1688 - val_accuracy: 0.9588
# Epoch 40/100
# 19/19 [==============================] - 1s 60ms/step - loss: 0.1982 - accuracy: 0.9532 - val_loss: 0.1499 - val_accuracy: 0.9471
# Epoch 41/100
# 19/19 [==============================] - 1s 60ms/step - loss: 0.1434 - accuracy: 0.9369 - val_loss: 0.0870 - val_accuracy: 0.9412
# Epoch 42/100
# 19/19 [==============================] - 1s 58ms/step - loss: 0.1561 - accuracy: 0.9522 - val_loss: 0.2132 - val_accuracy: 0.9353
# Epoch 43/100
# 19/19 [==============================] - 1s 60ms/step - loss: 0.2650 - accuracy: 0.9539 - val_loss: 0.0745 - val_accuracy: 0.9647
# Epoch 44/100
# 19/19 [==============================] - 1s 59ms/step - loss: 0.0755 - accuracy: 0.9520 - val_loss: 0.1264 - val_accuracy: 0.9765
# Epoch 45/100
# 19/19 [==============================] - 1s 59ms/step - loss: 0.1381 - accuracy: 0.9546 - val_loss: 0.0982 - val_accuracy: 0.9353
# Epoch 46/100
# 19/19 [==============================] - 1s 59ms/step - loss: 0.2316 - accuracy: 0.9314 - val_loss: 0.0673 - val_accuracy: 0.9765
# Epoch 47/100
# 19/19 [==============================] - 1s 60ms/step - loss: 0.1789 - accuracy: 0.9598 - val_loss: 0.4097 - val_accuracy: 0.9765
# Epoch 48/100
# 19/19 [==============================] - 1s 60ms/step - loss: 0.2616 - accuracy: 0.9669 - val_loss: 0.1893 - val_accuracy: 0.9706
# Epoch 49/100
# 19/19 [==============================] - 1s 60ms/step - loss: 0.1454 - accuracy: 0.9745 - val_loss: 0.0642 - val_accuracy: 0.9765
# Epoch 50/100
# 19/19 [==============================] - 1s 60ms/step - loss: 0.1629 - accuracy: 0.9673 - val_loss: 0.1412 - val_accuracy: 0.9765
# Epoch 51/100
# 19/19 [==============================] - 1s 60ms/step - loss: 0.1621 - accuracy: 0.9731 - val_loss: 0.0418 - val_accuracy: 0.9706
# Epoch 52/100
# 19/19 [==============================] - 1s 60ms/step - loss: 0.1429 - accuracy: 0.9584 - val_loss: 0.1908 - val_accuracy: 0.9529
# Epoch 53/100
# 19/19 [==============================] - 1s 60ms/step - loss: 0.2322 - accuracy: 0.9810 - val_loss: 0.1507 - val_accuracy: 0.9471
# Epoch 54/100
# 19/19 [==============================] - 1s 60ms/step - loss: 0.1593 - accuracy: 0.9593 - val_loss: 0.1783 - val_accuracy: 0.9471
# Epoch 55/100
# 19/19 [==============================] - 1s 60ms/step - loss: 0.1916 - accuracy: 0.9604 - val_loss: 0.1280 - val_accuracy: 0.9765
# Epoch 56/100
# 19/19 [==============================] - 1s 60ms/step - loss: 0.1000 - accuracy: 0.9864 - val_loss: 0.0978 - val_accuracy: 0.9471
# Epoch 57/100
# 19/19 [==============================] - 1s 59ms/step - loss: 0.1674 - accuracy: 0.9725 - val_loss: 0.1117 - val_accuracy: 0.9588
# Epoch 58/100
# 19/19 [==============================] - 1s 59ms/step - loss: 0.1142 - accuracy: 0.9599 - val_loss: 0.0675 - val_accuracy: 0.9941
# Epoch 59/100
# 19/19 [==============================] - 1s 59ms/step - loss: 0.1287 - accuracy: 0.9702 - val_loss: 0.1055 - val_accuracy: 0.9824
# Epoch 60/100
# 19/19 [==============================] - 1s 59ms/step - loss: 0.1552 - accuracy: 0.9627 - val_loss: 0.0880 - val_accuracy: 0.9765
# Epoch 61/100
# 19/19 [==============================] - 1s 59ms/step - loss: 0.1312 - accuracy: 0.9812 - val_loss: 0.0888 - val_accuracy: 0.9765
# Epoch 62/100
# 19/19 [==============================] - 1s 59ms/step - loss: 0.0941 - accuracy: 0.9737 - val_loss: 0.2778 - val_accuracy: 0.9176
# Epoch 63/100
# 19/19 [==============================] - 1s 59ms/step - loss: 0.2657 - accuracy: 0.9591 - val_loss: 0.0581 - val_accuracy: 0.9765
# Epoch 64/100
# 19/19 [==============================] - 1s 59ms/step - loss: 0.1095 - accuracy: 0.9597 - val_loss: 0.0583 - val_accuracy: 0.9765
# Epoch 65/100
# 19/19 [==============================] - 1s 59ms/step - loss: 0.1246 - accuracy: 0.9660 - val_loss: 0.0865 - val_accuracy: 0.9706
# Epoch 66/100
# 19/19 [==============================] - 1s 60ms/step - loss: 0.1250 - accuracy: 0.9585 - val_loss: 0.5522 - val_accuracy: 0.9941
# Epoch 67/100
# 19/19 [==============================] - 1s 58ms/step - loss: 0.2553 - accuracy: 0.9857 - val_loss: 0.1561 - val_accuracy: 0.9647
# Epoch 68/100
# 19/19 [==============================] - 1s 58ms/step - loss: 0.1199 - accuracy: 0.9508 - val_loss: 0.2149 - val_accuracy: 0.9824
# Epoch 69/100
# 19/19 [==============================] - 1s 60ms/step - loss: 0.1780 - accuracy: 0.9578 - val_loss: 0.2781 - val_accuracy: 0.9529
# Epoch 70/100
# 19/19 [==============================] - 1s 59ms/step - loss: 0.1765 - accuracy: 0.9670 - val_loss: 0.2082 - val_accuracy: 0.9706
# Epoch 71/100
# 19/19 [==============================] - 1s 59ms/step - loss: 0.1549 - accuracy: 0.9619 - val_loss: 0.0648 - val_accuracy: 0.9824
# Epoch 72/100
# 19/19 [==============================] - 1s 59ms/step - loss: 0.1012 - accuracy: 0.9365 - val_loss: 0.1161 - val_accuracy: 0.9882
# Epoch 73/100
# 19/19 [==============================] - 1s 59ms/step - loss: 0.1335 - accuracy: 0.9642 - val_loss: 0.1374 - val_accuracy: 0.9765
# Epoch 74/100
# 19/19 [==============================] - 1s 59ms/step - loss: 0.1197 - accuracy: 0.9651 - val_loss: 0.3524 - val_accuracy: 0.9824
# Epoch 75/100
# 19/19 [==============================] - 1s 59ms/step - loss: 0.1332 - accuracy: 0.9712 - val_loss: 0.0412 - val_accuracy: 0.9824
# Epoch 76/100
# 19/19 [==============================] - 1s 59ms/step - loss: 0.0724 - accuracy: 0.9625 - val_loss: 0.0597 - val_accuracy: 0.9941
# Epoch 77/100
# 19/19 [==============================] - 1s 59ms/step - loss: 0.1433 - accuracy: 0.9698 - val_loss: 0.1592 - val_accuracy: 0.9647
# Epoch 78/100
# 19/19 [==============================] - 1s 59ms/step - loss: 0.1044 - accuracy: 0.9634 - val_loss: 0.0502 - val_accuracy: 0.9882
# Epoch 79/100
# 19/19 [==============================] - 1s 59ms/step - loss: 0.0640 - accuracy: 0.9700 - val_loss: 0.0732 - val_accuracy: 0.9941
# Epoch 80/100
# 19/19 [==============================] - 1s 59ms/step - loss: 0.1167 - accuracy: 0.9602 - val_loss: 0.0236 - val_accuracy: 0.9765
# Epoch 81/100
# 19/19 [==============================] - 1s 59ms/step - loss: 0.0950 - accuracy: 0.9623 - val_loss: 0.0325 - val_accuracy: 0.9882
# Epoch 82/100
# 19/19 [==============================] - 1s 59ms/step - loss: 0.1120 - accuracy: 0.9697 - val_loss: 0.1890 - val_accuracy: 0.9941
# Epoch 83/100
# 19/19 [==============================] - 1s 59ms/step - loss: 0.1208 - accuracy: 0.9817 - val_loss: 0.0375 - val_accuracy: 0.9882
# Epoch 84/100
# 19/19 [==============================] - 1s 59ms/step - loss: 0.0764 - accuracy: 0.9766 - val_loss: 0.1640 - val_accuracy: 0.9706
# Epoch 85/100
# 19/19 [==============================] - 1s 59ms/step - loss: 0.0953 - accuracy: 0.9642 - val_loss: 0.0621 - val_accuracy: 0.9824
# Epoch 86/100
# 19/19 [==============================] - 1s 59ms/step - loss: 0.1165 - accuracy: 0.9700 - val_loss: 0.0982 - val_accuracy: 0.9765
# Epoch 87/100
# 19/19 [==============================] - 1s 59ms/step - loss: 0.0907 - accuracy: 0.9572 - val_loss: 0.0411 - val_accuracy: 0.9824
# Epoch 88/100
# 19/19 [==============================] - 1s 59ms/step - loss: 0.0950 - accuracy: 0.9703 - val_loss: 0.0669 - val_accuracy: 0.9765
# Epoch 89/100
# 19/19 [==============================] - 1s 60ms/step - loss: 0.0891 - accuracy: 0.9652 - val_loss: 0.0462 - val_accuracy: 0.9471
# Epoch 90/100
# 19/19 [==============================] - 1s 59ms/step - loss: 0.0891 - accuracy: 0.9578 - val_loss: 0.0252 - val_accuracy: 0.9765
# Epoch 91/100
# 19/19 [==============================] - 1s 59ms/step - loss: 0.0935 - accuracy: 0.9660 - val_loss: 0.2692 - val_accuracy: 0.9588
# Epoch 92/100
# 19/19 [==============================] - 1s 59ms/step - loss: 0.1315 - accuracy: 0.9609 - val_loss: 0.0774 - val_accuracy: 0.9765
# Epoch 93/100
# 19/19 [==============================] - 1s 60ms/step - loss: 0.0882 - accuracy: 0.9683 - val_loss: 0.0788 - val_accuracy: 0.9824
# Epoch 94/100
# 19/19 [==============================] - 1s 59ms/step - loss: 0.0954 - accuracy: 0.9632 - val_loss: 0.0887 - val_accuracy: 0.9706
# Epoch 95/100
# 19/19 [==============================] - 1s 59ms/step - loss: 0.0840 - accuracy: 0.9803 - val_loss: 0.0284 - val_accuracy: 0.9882
# Epoch 96/100
# 19/19 [==============================] - 1s 59ms/step - loss: 0.1033 - accuracy: 0.9720 - val_loss: 0.0640 - val_accuracy: 0.9824
# Epoch 97/100
# 19/19 [==============================] - 1s 60ms/step - loss: 0.1196 - accuracy: 0.9685 - val_loss: 0.0322 - val_accuracy: 0.9824
# Epoch 98/100
# 19/19 [==============================] - 1s 59ms/step - loss: 0.0795 - accuracy: 0.9697 - val_loss: 0.1786 - val_accuracy: 0.9824
# Epoch 99/100
# 19/19 [==============================] - 1s 59ms/step - loss: 0.1085 - accuracy: 0.9560 - val_loss: 0.0641 - val_accuracy: 0.9765
# Epoch 100/100
# 19/19 [==============================] - 1s 59ms/step - loss: 0.0976 - accuracy: 0.9637 - val_loss: 0.0252 - val_accuracy: 0.9941

# %%
# %matplotlib inline

import matplotlib.pyplot as plt


acc = history.history['accuracy']
val_acc = history.history['val_accuracy']


loss = history.history['loss']
val_loss = history.history['val_loss']


epochs = range(len(acc))

plt.plot(epochs, acc)
plt.plot(epochs, val_acc)
plt.title('Training and validation accuracy')

plt.figure()

plt.plot(epochs, loss)
plt.plot(epochs, val_loss)
plt.title('Training and validation loss')
# Out:
# Text(0.5, 1.0, 'Training and validation loss')

# %%
y_predictim=model.predict(X_test)

# %%
plt.plot(y_predictim[:,0],label="Predicted Amplitudes")
plt.plot(y_test[:,0],label="Reference Amplitudes")
plt.legend(loc="upper left")
plt.xlabel('Test Samples')
plt.ylabel('Amplitude(micrometer)')
plt.title('Comparison of Amplitude Estimation and Reference Amplitudes')
plt.show()

# %%
from sklearn.metrics import mean_squared_error
plt.plot(1000*(y_predictim[:,0]-y_test[:,0]),label="Amplitude Estimation Error")
plt.legend(loc="upper left")
plt.xlabel('Test Samples')
plt.ylabel('Amplitude(nanometer)')
plt.title('Amplitude Estimation Error with MSE='+str(1000*mean_squared_error(y_predictim[:,0], y_test[:,0]))+'nm')
plt.show()

# %%
plt.hist(1000*(y_predictim[:,0]-y_test[:,0]), bins = 10)
plt.xlabel('Amplitude(nanometer)')
plt.ylabel('Distribution')
plt.title('Distribution of Amplitude Estimation Error')
plt.show()

# %%
plt.plot(y_predictim[:,1],label="Predicted Frequencies")
plt.plot(y_test[:,1],label="Reference Frequencies")
plt.legend(loc="upper left")
plt.xlabel('Test Samples')
plt.ylabel('Frequency(hertz)')
plt.title('Comparison of Frequency Estimation and Reference Frequencies')
plt.show()

# %%
plt.plot(1000*(y_predictim[:,1]-y_test[:,1]),label="Frequency Estimation Error")
plt.legend(loc="upper left")
plt.xlabel('Test Samples')
plt.ylabel('Frequency(milihertz)')
plt.title('Frequency Estimation Error with MSE='+str(1000*mean_squared_error(y_predictim[:,1], y_test[:,1]))+'mHz')
plt.show()

# %%
plt.hist(1000*(y_predictim[:,1]-y_test[:,1]), bins = 20)
plt.xlabel('Frequency(milihertz)')
plt.ylabel('Distribution')
plt.title('Distribution of Frequency Estimation Error')
plt.show()
